# %%
import pandas as pd

# %%
df = pd.read_excel('dataset.xlsx')
df = df.drop(columns=['Patient ID', 'Patient addmited to regular ward (1=yes, 0=no)', 'Patient addmited to semi-intensive unit (1=yes, 0=no)', 'Patient addmited to intensive care unit (1=yes, 0=no)'])

# %%
def fillColumn(column_name):
    freq= df[column_name].value_counts()
    df[column_name].fillna(freq.index[0], inplace=True)

# %%
for column_name in df.columns:
  if(df[column_name].isnull().sum()>=(5644*.9)):
    print("Columna eliminada por dados Faltantes e/ou Inconsistentes: " + column_name)
    df.drop([column_name], axis='columns', inplace=True)
  else:
    fillColumn(column_name)
# Out:
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Serum Glucose
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Mycoplasma pneumoniae
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Neutrophils
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Urea
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Proteina C reativa mg/dL
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Creatinine
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Potassium
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Sodium
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Alanine transaminase
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Aspartate transaminase
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Gamma-glutamyltransferase
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Total Bilirubin
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Direct Bilirubin
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Indirect Bilirubin
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Alkaline phosphatase
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Ionized calcium
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Strepto A
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Magnesium
# Columna eliminada por dados Faltantes e/ou Inconsistentes: pCO2 (venous blood gas analysis)
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Hb saturation (venous blood gas analysis)
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Base excess (venous blood gas analysis)
# Columna eliminada por dados Faltantes e/ou Inconsistentes: pO2 (venous blood gas analysis)
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Fio2 (venous blood gas analysis)
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Total CO2 (venous blood gas analysis)
# Columna eliminada por dados Faltantes e/ou Inconsistentes: pH (venous blood gas analysis)
# Columna eliminada por dados Faltantes e/ou Inconsistentes: HCO3 (venous blood gas analysis)
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Rods #
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Segmented
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Promyelocytes
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Metamyelocytes
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Myelocytes
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Myeloblasts
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Urine - Esterase
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Urine - Aspect
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Urine - pH
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Urine - Hemoglobin
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Urine - Bile pigments
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Urine - Ketone Bodies
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Urine - Nitrite
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Urine - Density
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Urine - Urobilinogen
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Urine - Protein
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Urine - Sugar
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Urine - Leukocytes
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Urine - Crystals
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Urine - Red blood cells
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Urine - Hyaline cylinders
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Urine - Granular cylinders
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Urine - Yeasts
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Urine - Color
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Partial thromboplastin time (PTT)
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Relationship (Patient/Normal)
# Columna eliminada por dados Faltantes e/ou Inconsistentes: International normalized ratio (INR)
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Lactic Dehydrogenase
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Prothrombin time (PT), Activity
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Vitamin B12
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Creatine phosphokinase (CPK)
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Ferritin
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Arterial Lactic Acid
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Lipase dosage
# Columna eliminada por dados Faltantes e/ou Inconsistentes: D-Dimer
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Albumin
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Hb saturation (arterial blood gases)
# Columna eliminada por dados Faltantes e/ou Inconsistentes: pCO2 (arterial blood gas analysis)
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Base excess (arterial blood gas analysis)
# Columna eliminada por dados Faltantes e/ou Inconsistentes: pH (arterial blood gas analysis)
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Total CO2 (arterial blood gas analysis)
# Columna eliminada por dados Faltantes e/ou Inconsistentes: HCO3 (arterial blood gas analysis)
# Columna eliminada por dados Faltantes e/ou Inconsistentes: pO2 (arterial blood gas analysis)
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Arteiral Fio2
# Columna eliminada por dados Faltantes e/ou Inconsistentes: Phosphor
# Columna eliminada por dados Faltantes e/ou Inconsistentes: ctO2 (arterial blood gas analysis)

# %%
for column_name in df.columns:
      df[column_name] = df[column_name].astype('category').cat.codes

# %%
def  find_outliers_IQR(column_name):
    q= df[column_name].quantile([0.25, 0.5, 0.75])
    q1= q.values[0]
    q3= q.values[1]
    IQR= q3-q1
    outliers= df[(df[column_name] < q1-1.5*IQR) | (df[column_name] > q3+1.5*IQR)]
    return outliers

# %%
for column_name in df.columns:
  outliers = find_outliers_IQR(column_name)

# %%
# for column_name in outliers:
#     print(outliers)
